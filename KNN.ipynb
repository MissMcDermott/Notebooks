# %% [markdown]
# In this file we will implement and visualise KNN models. We will just be generating our own data so that we can actually visualise it

# %% [markdown]
# We have to do our imports as per usual

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import datasets, neighbors
from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_decision_regions

# %% [markdown]
# Our generation is below

# %%
X, y = datasets.make_blobs(n_samples=500, n_features=2, centers=4, cluster_std=1.5, random_state=4)

# %%
knn = neighbors.KNeighborsClassifier(n_neighbors= 5)
knn.fit(X, y)
# Out:
# KNeighborsClassifier()

# %%
plot_decision_regions(X, y, clf=knn, legend=2)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# Out:
# C:\Users\rmcdermott17\AppData\Roaming\Python\Python314\site-packages\mlxtend\plotting\decision_regions.py:346: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(

# %%
X2, y2 = datasets.make_blobs(n_samples=500, n_features=2, centers=4, cluster_std=2.5, random_state=10)

# %%
knn2 = neighbors.KNeighborsClassifier(n_neighbors= 5)
knn2.fit(X2, y2)
# Out:
# KNeighborsClassifier()

# %%
plot_decision_regions(X2, y2, clf=knn2, legend=2)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# Out:
# C:\Users\rmcdermott17\AppData\Roaming\Python\Python314\site-packages\mlxtend\plotting\decision_regions.py:346: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(
