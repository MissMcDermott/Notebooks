# %% [markdown]
# In this file you will be using logistic regression to predict outcomes

# %% [markdown]
# The first dataset to examine will be classifying an outcome of a hearing test based on age and their score

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv('data/hearing_test.csv')
df.info()

# %% [markdown]
# Make sure to use our means of checking what the data looks like and what data types there are

# %% [markdown]
# Take a look at to how the data affects the outcome. You can use subplots and/or a heatmap

# %% [markdown]
# Prepare your data

# %% [markdown]
# Create and fit your model. Feel free to vary the number of iterations to see how the performance of your model changes

# %% [markdown]
# Now test your model. You can use the classification report and the confusion matrix to measure performance

# %% [markdown]
# In this next one you will not be given a structure to work with. The next one will be predicting rainfall based on various measurements. You will need to map the outcomes to numbers, before creating your x and y data, as opposed to strings (refer to the multiple independent file if you have forgotten how to do so)

# %%
data = pd.read_csv('data/weather_forecast_data.csv')
