# %% [markdown]
# Within this file you will have to make your own linear regression models. First you will make a simple regression (1 independent variable). Then you will make a multiple linear regression model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# Below we read the dataset

# %%
df = pd.read_csv('data/Ice Cream Sales - temperatures.csv')

# %% [markdown]
# You should add code to get info on the dataset below

# %% [markdown]
# It would be good to plot the data using matplotlib. You will need to add code between the essential bits I have added below

# %%
plt.figure(figsize=(15,5))


plt.show()

# %% [markdown]
# Now we can make our model. Be sure to split the data into training and testing (not that it's a huge deal for linear regression models)

# %% [markdown]
# Let's plot the graph with our line of best fit below

# %% [markdown]
# And lastly, let's get some r2 values. I would recommend using the testing data as well as one of the training or full data to compare

# %% [markdown]
# If all went well then that is it for simple linear regression. If you want to make any predictions using your model please do so below

# %% [markdown]
# Alrighty, for the multiple independent variable linear regression model, you will be expected to work with less guidance. The dataset I have included for this section is Food_Delivery_times. You will have to make your own code blocks (and ideally some markdown to explain things). Work with others if you want to, ask questions if you need to. Good luck!
